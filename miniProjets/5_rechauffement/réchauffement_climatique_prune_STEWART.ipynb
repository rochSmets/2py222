# %% [markdown]
# # Réchauffement climatique

# %%
import numpy as np
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt

# %%
data = np.loadtxt('montelimar_temperature.dat')
jour, temp = data[:,0], data[:,1]
date = (jour + 2400000.5)/365.25 - 4713.5

# %%
print(date)
# Out:
# [1919.09000684 1919.0927447  1919.09548255 ... 2018.45482546 2018.45756331
#  2018.46030116]

# %%
def f(x, a, b):
    return a*x +b

ajust, covariance = curve_fit(f, date, temp)

aj, bj = ajust

temperature = aj*date + bj

plt.plot(date, temp)
plt.plot(date, temperature)

# %% [markdown]
# ### Contrôle Continu - LU2PY222 : Modélisation Numérique en Physique
# #### 5 mars 2025, 10h45 - 12h45
#
# Vous rendrez sur Moodle un **compte-rendu** sous la forme d'un calepin **Jupyter** comprenant :
# - vos codes python (bien commentés)
# - vos graphiques (axes nommés et courbes légendées lorsque c'est nécessaire)
# - les commentaires des résultats sous format Markdown lorsque c'est demandé
#
# Vous avez le droit d'accéder à tous les calepins jupyter présents sur votre Hub, ainsi qu'à vos notes (manuscrites ou numériques) prises pendant les séances de travail de cette UE. L'accès à internet est limité aux sites de documentation **python**, **numpy** et **matplotlib**, et à Moodle. Vos documents numériques doivent être présents dans vos fichiers personnels Moodle. Les clés USB, smartphones et tablettes ne sont pas acceptées.
#
# # Particule dans un cyclotron
#
# Un cyclotron comporte trois parties, voir la figure ci-dessous. Les parties supérieure et inférieure, appelées "D" à cause de la forme de la trajectoire, sont plongées dans un champ magnétique.
#
# ![](Figure3.png)
#
# Au temps $t_0=0$ **(ici le temps est sans unité)**, un proton est injecté au niveau du D inférieur sans vitesse. Une tension alternative est appliquée entre les D. Elle crée un champ électrique dont la direction et le sens sont toujours **similaires** à ceux de la vitesse du proton lorsqu’il est entre les D. Les instants $t_n$ où le proton sort des D (soit inférieur, soit supérieur, voir la figure) sont donnés, **sans unité**, par
# $$t_n=n+\tau \sqrt{n}.$$
# On choisit $\tau=0.5$. Le temps passé par le proton dans un D (supérieur ou inférieur) est toujours de $1$.
# La trajectoire du proton est plane. On s’intéresse à sa vitesse. Ses composantes sont données, dans un repère et des unités appropriés, **en fonction de sa position dans le cyclotron:**
# 1) Pour $t$ variant de $t_n$ à $t_{n+1}-1$ c’est-à-dire quand il est entre les D :
# $$
# v_x(t) = 0  \qquad  v_y(t) = \epsilon_n \left( \sqrt{n} + (t-t_n)/\tau \right)
# $$
# 2) Pour $t$ variant de $t_{n+1}-1$ à $t_{n+1}$ c’est-à-dire quand il est dans D supérieur ou D inférieur.
# $$
# v_x(t) = \epsilon_n \sqrt{n+1} \sin \left( \pi (t-t_{n+1}) \right) \qquad v_y(t) = -\epsilon_n \sqrt{n+1} \cos \left( \pi (t-t_{n+1}) \right)
# $$
#
# Dans ces expressions, $\epsilon_n$ vaut $1$ pour $n$ pair et $-1$ pour $n$ impair. On pourra prendre $\epsilon_n = (-1)^n$.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Partie I
#
# 1. Créer un tableau contenant les instants de sortie des boucles "D" : $t_0$, $t_1$, ... jusqu'à $t_{50}$ inclus.
# 2. Vérifier que $t_1=1.5$, $t_4=5$, $t_9=10.5$, $t_{16}=18$, et $t_{25}=27.5$ avec des opérateurs booléens.
# 3. Calculer les valeurs de $v_x$ et $v_y$ en fonction du temps pour $t$ variant de $t_2−1$ à $t_2$. Vous utiliserez un échantillonage suffisant pour le temps $t$, dans un tableau distinct de celui de la question précédente. Faire de même pour $t$ variant de $t_4-1$ à $t_4$.
# 4. Représenter dans un graphique $v_x$ et $v_y$ en fonction de $t$ pour $t$ variant de $t_2-1$ a $t_2$. Faire de même pour $t$ variant de $t_4-1$ à $t_4$.
# 5. Déterminer des valeurs approchées des maxima de $v_x$ et $v_y$ pour $t$ variant de $t_2-1$ à $t_2$, ainsi que les instants $t$ correspondants. Un maximum peut être en bord d'intervalle. Faire de même pour $t$ variant de $t_4-1$ à $t_4$. Commenter.

# %% [markdown]
# 1.

# %%
t0 = 0
tho = 0.5
n_max = 50
n = np.linspace(0,n_max,n_max+1)

tn = n + tho*np.sqrt(n)

# %% [markdown]
# 2.

# %%
print("t1 = 1.5 ? ",tn[1]==1.5)
print("t4 = 5 ? ",tn[4]==5)
print("t9 = 10.5 ? ",tn[9]==10.5)
print("t16 = 18 ? ",tn[16]==18)
print("t25 = 27.5 ? ",tn[25]==27.5)
# Out:
# t1 = 1.5 ?  True
# t4 = 5 ?  True
# t9 = 10.5 ?  True
# t16 = 18 ?  True
# t25 = 27.5 ?  True

# %% [markdown]
# 3.

# %%
n_i_2 = 1
t_t2 = np.linspace(tn[n_i_2]-1,tn[n_i_2],100)

vx_t2 = np.sqrt(n[n_i_2]+1)*np.sin(np.pi*(t_t2-tn[n_i_2]))*(-1)**n[n_i_2]
vy_t2 = -np.sqrt(n[n_i_2]+1)*np.cos(np.pi*(t_t2-tn[n_i_2]))*(-1)**n[n_i_2]


n_i_4 = 3
t_t4 = np.linspace(tn[n_i_4]-1,tn[n_i_4],100)

vx_t4 = np.sqrt(n[n_i_4]+1)*np.sin(np.pi*(t_t4-tn[n_i_4]))*(-1)**n[n_i_4]
vy_t4 = -np.sqrt(n[n_i_4]+1)*np.cos(np.pi*(t_t4-tn[n_i_4]))*(-1)**n[n_i_4]

# %% [markdown]
# 4.

# %%
plt.plot(t_t2,vx_t2,label = "vx entre t2-1 et t2")
plt.plot(t_t2,vy_t2,label = "vy entre t2-1 et t2")
plt.title("vx et vy en fonction t variant entre t2-1 et t2")
plt.xlabel("temps")
plt.ylabel("vitesse")
plt.legend()
plt.show()

plt.plot(t_t4,vx_t4,label = "vx entre t4-1 et t4")
plt.plot(t_t4,vy_t4,label = "vy entre t4-1 et t4")
plt.title("vx et vy en fonction t variant entre t4-1 et t4")
plt.xlabel("temps")
plt.ylabel("vitesse")
plt.legend()
plt.show()

# %% [markdown]
# 5.

# %%
max_vx_t2 =0
max_vx_t2_t = 0

for i,v in enumerate(vx_t2):
    if v>max_vx_t2 :
        max_vx_t2 = v
        max_vx_t2_t = t_t2[i]

max_vy_t2 =0
max_vy_t2_t = 0

for i,v in enumerate(vy_t2):
    if v>max_vy_t2 :
        max_vy_t2 = v
        max_vy_t2_t = t_t2[i]

print("maxima vx pour t entre t2-1 et t2: ",max_vx_t2," t associé : ",max_vx_t2_t)
print("maxima vy pour t entre t2-1 et t2: ",max_vy_t2," t associé : ",max_vy_t2_t)

max_vx_t4 =0
max_vx_t4_t = 0

for i,v in enumerate(vx_t4):
    if v>max_vx_t4 :
        max_vx_t4 = v
        max_vx_t4_t = t_t4[i]

max_vy_t4 =0
max_vy_t4_t = 0

for i,v in enumerate(vy_t4):
    if v>max_vy_t4 :
        max_vy_t4 = v
        max_vy_t4_t = t_t4[i]

print("maxima vx pour t entre t4-1 et t4: ",max_vx_t4," t associé : ",max_vx_t4_t)
print("maxima vy pour t entre t4-1 et t4: ",max_vy_t4," t associé : ",max_vy_t4_t)
# Out:
# maxima vx pour t entre t2-1 et t2:  1.414035552022362  t associé :  0.994949494949495
# maxima vy pour t entre t2-1 et t2:  1.4142135623730951  t associé :  1.5
# maxima vx pour t entre t4-1 et t4:  1.9997482553477504  t associé :  3.360974898733933
# maxima vy pour t entre t4-1 et t4:  2.0  t associé :  3.8660254037844384

# %% [markdown]
# Les valeurs maximales de vx et vy sont quasiment égales. De plus losrque l'un est maximisé l'autre est nul. On peut supposer que la norme de la vitesse est conservée pendant quand le photon est dans les D.

# %% [markdown]
# ## Partie II
# 6. Représenter $v_x$ et $v_y$ en fonction de $t$ pour $t$ variant de $0$ à $t_6$. On utilisera une couleur unique pour la courbe par morceaux. On remarque que $v_x$ et $v_y$ sont des fonctions continues du temps $t$. Commenter.
# 7. Représenter le module de la vitesse $\sqrt{v_x^2+v_y^2}$ en fonction de $t$ pour $t$ variant de $0$ à $t_6$. On utilisera une couleur unique pour la courbe par morceaux. Commenter. A quoi sert un cyclotron ?
# 8. Pour $n$ variant de $0$ à $50$, représenter le module de la vitesse $\sqrt{v_x(t_n)^2+v_y(t_n)^2}$ en fonction de $t_n-n$, qui est le temps total passé par le proton entre les D à l'instant $t_n$. Commenter.

# %% [markdown]
# 6.

# %%
def V_x_D(n,t) :
    return np.sqrt(n+1)*np.sin(np.pi*(t-tn[n+1]))*(-1)**n
def V_y_D(n,t) :
    return -np.sqrt(n+1)*np.cos(np.pi*(t-tn[n+1]))*(-1)**n

def V_x():
    return np.zeros(100)
def V_y(n,t):
    return (np.sqrt(n)+(t-tn[n])/tho)*(-1)**n

# %%
t = np.array([np.linspace(tn[0],tn[1]-1,100),np.linspace(tn[1]-1,tn[1],100),np.linspace(tn[1],tn[2]-1,100),np.linspace(tn[2]-1,tn[2],100),np.linspace(tn[2],tn[3]-1,100),np.linspace(tn[3]-1,tn[3],100),np.linspace(tn[3],tn[4]-1,100),np.linspace(tn[4]-1,tn[4],100),np.linspace(tn[4],tn[5]-1,100),np.linspace(tn[5]-1,tn[5],100),np.linspace(tn[5],tn[6]-1,100),np.linspace(tn[6]-1,tn[6],100)])
v_x = np.array([V_x(),V_x_D(0,t[1]),V_x(),V_x_D(1,t[3]),V_x(),V_x_D(2,t[5]),V_x(),V_x_D(3,t[7]),V_x(),V_x_D(4,t[9]),V_x(),V_x_D(5,t[11])])
v_y = np.array([V_y(0,t[0]),V_y_D(0,t[1]),V_y(1,t[2]),V_y_D(1,t[3]),V_y(2,t[4]),V_y_D(2,t[5]),V_y(3,t[6]),V_y_D(3,t[7]),V_y(4,t[8]),V_y_D(4,t[9]),V_y(5,t[10]),V_y_D(5,t[11])])

# %%
for i in range(len(t)):
    plt.plot(t[i],v_x[i])
plt.title("vx en fonction de t")
plt.xlabel("temps")
plt.ylabel("vitesse")
plt.show()
for i in range(len(t)):
    plt.plot(t[i],v_y[i])
plt.title("vy enfonction de t")
plt.xlabel("temps")
plt.ylabel("vitesse")
plt.show()

# %% [markdown]
# Les maximums des vitesses augmentent chaque foit que la particule passe entre les D

# %% [markdown]
# 7.

# %%
v_norme = np.array([])
for i in range(len(v_x)):
    v_norme = np.append(v_norme,np.sqrt(v_x[i]**2 +v_y[i]**2))

plt.plot(t.flatten(),v_norme)
plt.title("norme de la vitesse en fonction de t")
plt.xlabel("temps")
plt.ylabel("vitesse")
plt.show()

# %% [markdown]
# 8.

# %%
for i in range(len(tn)-1):
    t = np.linspace(tn[i],t[i+1]-1,100)
    t_D = np.linspace(t[i+1]-1,t[i+1],100)
    v_norme  = np.sqrt(V_x()**2 + V_y(i,t))
    v_norme_D = np.sqrt(V_x_D(i,t_D)**2 + V_y_D(i,t_D))
    plt.plot(t,v_norme)
    plt.plot(t_D,v_norme_D)
# Out:
# /tmp/ipykernel_551728/884311230.py:5: RuntimeWarning: invalid value encountered in sqrt
#   v_norme_D = np.sqrt(V_x_D(i,t_D)**2 + V_y_D(i,t_D))
# /tmp/ipykernel_551728/884311230.py:4: RuntimeWarning: invalid value encountered in sqrt
#   v_norme  = np.sqrt(V_x()**2 + V_y(i,t))

# %% [markdown]
# ### Contrôle Continu - LU2PY222 : Modélisation Numérique en Physique
# #### 5 mars 2025, 10h45 - 12h45
#
# Vous rendrez sur Moodle un **compte-rendu** sous la forme d'un calepin **Jupyter** comprenant :
# - vos codes python (bien commentés)
# - vos graphiques (axes nommés et courbes légendées lorsque c'est nécessaire)
# - les commentaires des résultats sous format Markdown lorsque c'est demandé
#
# Vous avez le droit d'accéder à tous les calepins jupyter présents sur votre Hub, ainsi qu'à vos notes (manuscrites ou numériques) prises pendant les séances de travail de cette UE. L'accès à internet est limité aux sites de documentation **python**, **numpy** et **matplotlib**, et à Moodle. Vos documents numériques doivent être présents dans vos fichiers personnels Moodle. Les clés USB, smartphones et tablettes ne sont pas acceptées.
#
# # Particule dans un cyclotron
#
# Un cyclotron comporte trois parties, voir la figure ci-dessous. Les parties supérieure et inférieure, appelées "D" à cause de la forme de la trajectoire, sont plongées dans un champ magnétique.
#
# ![](Figure3.png)
#
# Au temps $t_0=0$ **(ici le temps est sans unité)**, un proton est injecté au niveau du D inférieur sans vitesse. Une tension alternative est appliquée entre les D. Elle crée un champ électrique dont la direction et le sens sont toujours **similaires** à ceux de la vitesse du proton lorsqu’il est entre les D. Les instants $t_n$ où le proton sort des D (soit inférieur, soit supérieur, voir la figure) sont donnés, **sans unité**, par
# $$t_n=n+\tau \sqrt{n}.$$
# On choisit $\tau=0.5$. Le temps passé par le proton dans un D (supérieur ou inférieur) est toujours de $1$.
# La trajectoire du proton est plane. On s’intéresse à sa vitesse. Ses composantes sont données, dans un repère et des unités appropriés, **en fonction de sa position dans le cyclotron:**
# 1) Pour $t$ variant de $t_n$ à $t_{n+1}-1$ c’est-à-dire quand il est entre les D :
# $$
# v_x(t) = 0  \qquad  v_y(t) = \epsilon_n \left( \sqrt{n} + (t-t_n)/\tau \right)
# $$
# 2) Pour $t$ variant de $t_{n+1}-1$ à $t_{n+1}$ c’est-à-dire quand il est dans D supérieur ou D inférieur.
# $$
# v_x(t) = \epsilon_n \sqrt{n+1} \sin \left( \pi (t-t_{n+1}) \right) \qquad v_y(t) = -\epsilon_n \sqrt{n+1} \cos \left( \pi (t-t_{n+1}) \right)
# $$
#
# Dans ces expressions, $\epsilon_n$ vaut $1$ pour $n$ pair et $-1$ pour $n$ impair. On pourra prendre $\epsilon_n = (-1)^n$.

# %% [markdown]
# ## Partie I
#
# 1. Créer un tableau contenant les instants de sortie des boucles "D" : $t_0$, $t_1$, ... jusqu'à $t_{50}$ inclus.
# 2. Vérifier que $t_1=1.5$, $t_4=5$, $t_9=10.5$, $t_{16}=18$, et $t_{25}=27.5$ avec des opérateurs booléens.
# 3. Calculer les valeurs de $v_x$ et $v_y$ en fonction du temps pour $t$ variant de $t_2−1$ à $t_2$. Vous utiliserez un échantillonage suffisant pour le temps $t$, dans un tableau distinct de celui de la question précédente. Faire de même pour $t$ variant de $t_4-1$ à $t_4$.
# 4. Représenter dans un graphique $v_x$ et $v_y$ en fonction de $t$ pour $t$ variant de $t_2-1$ a $t_2$. Faire de même pour $t$ variant de $t_4-1$ à $t_4$.
# 5. Déterminer des valeurs approchées des maxima de $v_x$ et $v_y$ pour $t$ variant de $t_2-1$ à $t_2$, ainsi que les instants $t$ correspondants. Un maximum peut être en bord d'intervalle. Faire de même pour $t$ variant de $t_4-1$ à $t_4$. Commenter.

# %%
# Question 1
# 

import numpy as np
import math

# tableau contenant tous les temps de sortie de t0 à t50 soit 51 éléments
N = 51
tau = 0.5

# initialisé avec des zéro
t_sortie = np.zeros(N) 

for i in range(N):
    t_sortie[i] = i + tau * math.sqrt(i)
    
# Question 2
#

# Vérification pour t1
if t_sortie[1] == 1.5:
    print("La valeur de t1 est bonne")
else:
    print("La valeur de t1 n'est pas bonne")
    
# vérification pour t4    
if t_sortie[4] == 5:
    print("La valeur de t4 est bonne")
else:
    print("La valeur de t4 n'est pas bonne")

# vérification pour t9    
if t_sortie[9] == 10.5:
    print("La valeur de t9 est bonne")
else:
    print("La valeur de t9 n'est pas bonne")

# vérification pour t16    
if t_sortie[16] == 18:
    print("La valeur de t16 est bonne")
else:
    print("La valeur de t16 n'est pas bonne")

# vérification pour t25    
if t_sortie[25] == 27.5:
    print("La valeur de t25 est bonne")
else:
    print("La valeur de t25 n'est pas bonne")
# Out:
# La valeur de t1 est bonne
# La valeur de t4 est bonne
# La valeur de t9 est bonne
# La valeur de t16 est bonne
# La valeur de t25 est bonne

# %% [markdown]
# ## Partie I
#
# 1. Créer un tableau contenant les instants de sortie des boucles "D" : $t_0$, $t_1$, ... jusqu'à $t_{50}$ inclus.
# 2. Vérifier que $t_1=1.5$, $t_4=5$, $t_9=10.5$, $t_{16}=18$, et $t_{25}=27.5$ avec des opérateurs booléens.
# 3. Calculer les valeurs de $v_x$ et $v_y$ en fonction du temps pour $t$ variant de $t_2−1$ à $t_2$. Vous utiliserez un échantillonage suffisant pour le temps $t$, dans un tableau distinct de celui de la question précédente. Faire de même pour $t$ variant de $t_4-1$ à $t_4$.
# 4. Représenter dans un graphique $v_x$ et $v_y$ en fonction de $t$ pour $t$ variant de $t_2-1$ a $t_2$. Faire de même pour $t$ variant de $t_4-1$ à $t_4$.
# 5. Déterminer des valeurs approchées des maxima de $v_x$ et $v_y$ pour $t$ variant de $t_2-1$ à $t_2$, ainsi que les instants $t$ correspondants. Un maximum peut être en bord d'intervalle. Faire de même pour $t$ variant de $t_4-1$ à $t_4$. Commenter.
#
#
# On choisit $\tau=0.5$. Le temps passé par le proton dans un D (supérieur ou inférieur) est toujours de $1$.
# La trajectoire du proton est plane. On s’intéresse à sa vitesse. Ses composantes sont données, dans un repère et des unités appropriés, **en fonction de sa position dans le cyclotron:**
# 1) Pour $t$ variant de $t_n$ à $t_{n+1}-1$ c’est-à-dire quand il est entre les D :
# $$
# v_x(t) = 0  \qquad  v_y(t) = \epsilon_n \left( \sqrt{n} + (t-t_n)/\tau \right)
# $$
# 2) Pour $t$ variant de $t_{n+1}-1$ à $t_{n+1}$ c’est-à-dire quand il est dans D supérieur ou D inférieur.
# $$
# v_x(t) = \epsilon_n \sqrt{n+1} \sin \left( \pi (t-t_{n+1}) \right) \qquad v_y(t) = -\epsilon_n \sqrt{n+1} \cos \left( \pi (t-t_{n+1}) \right)
# $$
#
# Dans ces expressions, $\epsilon_n$ vaut $1$ pour $n$ pair et $-1$ pour $n$ impair. On pourra prendre $\epsilon_n = (-1)^n$.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Question 3

epsilon = -1

# Les vitesses de (t_n) à (t_n+1) - 1
def vitesseX_N_N1(t):
    # la vitesse est toujours à zéro
    return 0

def vitesseY_N_N1(t, n):
    # 
    return ( (epsilon)**n * ( math.sqrt(n) + (t - t_sortie[n])/tau ) ) 
        

# Les vitesses de (t_n+1) - 1  à (t_n+1)
def vitesseX_N1_N1(t,n):
    #
    return (epsilon)**n * math.sqrt(n+1) * math.sin( math.pi * ( t - t_sortie[n] )) 

def vitesseY_N1_N1(t, n):
    #
    return -(epsilon)**n * math.sqrt( n + 1 ) * math.cos ( math.pi * (t - t_sortie[n+1]) )

#--------------------------------------------------------------------------------

# Pour t2-1 à t2
# donc n = 1

# Découpage pour le temps
decoupe_temps = 100

# génération d'un "grand nombre de valeurs" pour le temps
t_values = np.linspace(t_sortie[1]-1, t_sortie[1], decoupe_temps)

#
# 2 listes pour le stockage des résultats
vx_resultat_2 = []
vy_resultat_2 = []

for i in t_values:
    vx_resultat_2.append( vitesseX_N1_N1(i,1) )
    vy_resultat_2.append( vitesseY_N1_N1(i, 1) )

# Conversion en tableau numpy
vx_resultat_2 = np.array(vx_resultat_2)
vy_resultat_2 = np.array(vy_resultat_2)


# Tracé de Vx en fonction du temps
plt.figure(figsize=(10, 6))
plt.plot(t_values, vx_resultat_2 , marker='o', color='red', markersize=0.5)  # Petits points noirs
plt.title("t2 -1 à t2 : Vx en fonction du temps pour n = 1 ")
plt.xlabel("temps")
plt.ylabel("Vx")
plt.grid(True)
plt.show()

# Tracé de Vy en fonction du temps
plt.figure(figsize=(10, 6))
plt.plot(t_values, vy_resultat_2 , marker='o', color='blue', markersize=0.5)  # Petits points noirs
plt.title("t2 -1 à t2 : Vy en fonction du temps pour n = 1 ")
plt.xlabel("temps")
plt.ylabel("Vy")
plt.grid(True)
plt.show()

# Vitesses maxi et temps associés

# pour Vx
vx_max_n1 = np.max( vx_resultat_2 )
print("La vitesse maximum pour Vx quand n=1 est : ", vx_max_n1 )

# recherche de l'indice
indice = 0
for i in range(len (vx_resultat_2) ) :
    if vx_resultat_2[i] == vx_max_n1:
        indice = i
        break
print("Le temps est : ", t_values[indice] )
    
# pour Vy
vy_max_n1 = np.max( vy_resultat_2 )
print("La vitesse maximum pour Vy quand n=1 est : ", vy_max_n1 )

# recherche de l'indice
indice = 0
for i in range(len (vy_resultat_2) ) :
    if vy_resultat_2[i] == vy_max_n1:
        indice = i
        break
print("Le temps est : ", t_values[indice] )

#---------------------------------------------------------------
# pour t4-1 à t4
# donc n = 3

# Découpage pour le temps
decoupe_temps = 100

# génération d'un "grand nombre de valeurs" pour le temps
t_values = np.linspace(t_sortie[3]-1, t_sortie[3], decoupe_temps)

#
# 2 listes pour le stockage des résultats
vx_resultat_4 = []
vy_resultat_4 = []

for i in t_values:
    vx_resultat_4.append( vitesseX_N1_N1(i,3) )
    vy_resultat_4.append( vitesseY_N1_N1(i,3) )

# Conversion en tableau numpy
vx_resultat_4 = np.array(vx_resultat_4)
vy_resultat_4 = np.array(vy_resultat_4)


# Tracé de Vx en fonction du temps
plt.figure(figsize=(10, 6))
plt.plot(t_values, vx_resultat_4 , marker='o', color='red', markersize=0.5)  # Petits points noirs
plt.title("t4 -1 à t4 : Vx en fonction du temps pour n = 3 ")
plt.xlabel("temps")
plt.ylabel("Vx")
plt.grid(True)
plt.show()

# Tracé de Vy en fonction du temps
plt.figure(figsize=(10, 6))
plt.plot(t_values, vy_resultat_4 , marker='o', color='blue', markersize=0.5)  # Petits points noirs
plt.title("t4 -1 à t4 : Vy en fonction du temps pour n = 3 ")
plt.xlabel("temps")
plt.ylabel("Vy")
plt.grid(True)
plt.show()

# Vitesses maxi et temps associés

# pour Vx
vx_max_n3 = np.max( vx_resultat_4 )
print("La vitesse maximum pour Vx quand n=1 est : ", vx_max_n3 )

# recherche de l'indice
indice = 0
for i in range(len (vx_resultat_4) ) :
    if vx_resultat_4[i] == vx_max_n3:
        indice = i
        break
print("Le temps est : ", t_values[indice] )
    
# pour Vy
vy_max_n3 = np.max( vy_resultat_4 )
print("La vitesse maximum pour Vy quand n=3 est : ", vy_max_n3 )

# recherche de l'indice
indice = 0
for i in range(len (vy_resultat_4) ) :
    if vy_resultat_4[i] == vy_max_n3:
        indice = i
        break
print("Le temps est : ", t_values[indice] )
# Out:
# La vitesse maximum pour Vx quand n=1 est :  1.4140355520223618
# Le temps est :  0.994949494949495
# La vitesse maximum pour Vy quand n=1 est :  1.4140380858284038
# Le temps est :  0.7121212121212122
# La vitesse maximum pour Vx quand n=1 est :  1.9997482553477501
# Le temps est :  3.360974898733933
# La vitesse maximum pour Vy quand n=3 est :  1.999930090096607
# Le temps est :  2.99733853509757

# %%
# Commentaire

# Le cyclotron permet d'accèlérer les particules à chaque passage.
# Il s'agit d'une boucle qui accèlére les particules

# %% [markdown]
# ## Partie II
# 6. Représenter $v_x$ et $v_y$ en fonction de $t$ pour $t$ variant de $0$ à $t_6$. On utilisera une couleur unique pour la courbe par morceaux. On remarque que $v_x$ et $v_y$ sont des fonctions continues du temps $t$. Commenter.
# 7. Représenter le module de la vitesse $\sqrt{v_x^2+v_y^2}$ en fonction de $t$ pour $t$ variant de $0$ à $t_6$. On utilisera une couleur unique pour la courbe par morceaux. Commenter. A quoi sert un cyclotron ?
# 8. Pour $n$ variant de $0$ à $50$, représenter le module de la vitesse $\sqrt{v_x(t_n)^2+v_y(t_n)^2}$ en fonction de $t_n-n$, qui est le temps total passé par le proton entre les D à l'instant $t_n$. Commenter.

# %%
#
# Découpage pour le temps
decoupe_temps = 100

#
# 2 listes pour le stockage des résultats
vx_resultat = []
vy_resultat = []
t_total = []

#
for i in range(6):  
    # partie  tn vers tn - 1
    t_values = np.linspace(t_sortie[i], t_sortie[i+1]-1, decoupe_temps)
    t_total.append(t_values)
    #
    for j in t_values:       
        vx_resultat.append( vitesseX_N_N1(j) )
        vy_resultat.append( vitesseY_N_N1(j,i) )
    
    # partie  tn - 1 vers tn
    t_values = np.linspace(t_sortie[i+1]-1, t_sortie[i+1], decoupe_temps)
    t_total.append(t_values)
    #
    for k in t_values:       
        vx_resultat.append( vitesseX_N1_N1(k,i+1) )
        vy_resultat.append( vitesseY_N1_N1(k,i+1) )

# Conversion en tableau numpy
vx_resultat = np.array(vx_resultat)
vy_resultat = np.array(vy_resultat)
t_total = np.array(t_total)
t_total = t_total.flatten()

# Tracé de Vx en fonction du temps
plt.figure(figsize=(10, 6))
plt.plot(t_total, vx_resultat , marker='o', color='red', markersize=0.5)
plt.title("t0 à t6 : Vx en fonction du temps")
plt.xlabel("temps")
plt.ylabel("Vx")
plt.grid(True)
plt.show()

# Tracé de Vy en fonction du temps
plt.figure(figsize=(10, 6))
plt.plot(t_total, vy_resultat , marker='o', color='blue', markersize=0.5)
plt.title("t0 à t6 : Vy en fonction du temps")
plt.xlabel("temps")
plt.ylabel("Vy")
plt.grid(True)
plt.show()

# %%
#
resultat = vy_resultat**2 + vx_resultat**2 

resultat = np.sqrt( resultat )


# Tracé du module de la vitesse  en fonction du temps
plt.figure(figsize=(10, 6))
plt.plot(t_total, resultat , marker='o', color='red', markersize=0.5)
plt.title("t0 à t6 : module de la vitesse en fonction du temps")
plt.xlabel("temps")
plt.ylabel("module de la vitesse")
plt.grid(True)
plt.show()

# %% [markdown]
# #  Contrôle Continu - LU2PY222 : Modélisation Numérique en Physique
# ### Andry Blanche Mono 2A

# %% [markdown]
# ## Partie  1
#
# 1. Créer un tableau contenant les instants de sortie des boucles "D" : $t_0$, $t_1$, ... jusqu'à $t_{50}$ inclus.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
to= 0.5
t= np.arange(0,51,1) + to*np.sqrt(np.arange(0,51,1))

# %% [markdown]
# 2. Vérifier que $t_1=1.5$, $t_4=5$, $t_9=10.5$, $t_{16}=18$, et $t_{25}=27.5$ avec des opérateurs booléens.

# %%
print(t[1]==1.5)   # verification de t_1=1.5
print(t[4]==5)     # verification de t_4=5
print(t[16]==18)   # verification de t_16=18
print(t[25]==27.5) # verification de t_25=27.5
# Out:
# True
# True
# True
# True

# %% [markdown]
# 3. Calculer les valeurs de $v_x$ et $v_y$ en fonction du temps pour $t$ variant de $t_2−1$ à $t_2$. Vous utiliserez un échantillonage suffisant pour le temps $t$, dans un tableau distinct de celui de la question précédente. Faire de même pour $t$ variant de $t_4-1$ à $t_4$.

# %%
# Calculer les valeurs de  𝑣𝑥 et  𝑣𝑦 en fonction du temps pour  𝑡 variant de  𝑡2−1 à  𝑡2

time= np.arange(0,2,0.01) + to*np.sqrt(np.arange(0,2,0.01))
t2=[]

for i in time:
    if (t[2]-1)<=i<=t[2]:
        t2.append(i)
        
t_2=np.array(t2)
vx_2=np.zeros(len(t_2))
vy_2=np.zeros(len(t_2))

for i in range (len(t_2)-1):
    vx_2[i]= ((-1)**2)*np.sqrt(1+2)*np.sin(np.pi*(t_2[i]-t[2]))
    vy_2[i]= ((-(-1)**2))*np.sqrt(1+2)*np.cos(np.pi*(t_2[i]-t[2]))

# %%
# Calculer les valeurs de  𝑣𝑥 et  𝑣𝑦 en fonction du temps pour  𝑡 variant de  𝑡4−1 à  𝑡4
time4= np.arange(0,4,0.01) + to*np.sqrt(np.arange(0,4,0.01))
t4=[]

for i in time4:
    if (t[4]-1)<=i<=t[4]:
        t4.append(i)
        
t_4=np.array(t4)
vx_4=np.zeros(len(t_4))
vy_4=np.zeros(len(t_4))

for i in range (len(t_4)-1):
    vx_4[i]= ((-1)**4)*np.sqrt(4+1)*np.sin(np.pi*(t_4[i]-t[4]))
    vy_4[i]= ((-(-1)**4))*np.sqrt(4+1)*np.cos(np.pi*(t_4[i]-t[4]))

# %% [markdown]
# 4. Représenter dans un graphique $v_x$ et $v_y$ en fonction de $t$ pour $t$ variant de $t_2-1$ a $t_2$. Faire de même pour $t$ variant de $t_4-1$ à $t_4$.

# %%
# Représentation graphique de vx et vy en fonction de t pour t variant de t2 à t2-1
plt.plot(t_2,vx_2,'r',label='vx')
plt.plot(t_2,vy_2,'g', label='vy')
plt.xlabel('temps variant de t2 à t2-1')
plt.ylabel(' vx et vy ')
plt.title( 'vx et vy en fonction de t pour t variant de t2 à t2-1')
plt.legend()
plt.show()

# %%
# Représentation graphique de vx et vy en fonction de t pour t variant de t4 à t4-1
plt.plot(t_4,vx_4,'r',label='vx')
plt.plot(t_4,vy_4,'g', label='vy')
plt.xlabel('temps variant de t4 à t4-1')
plt.ylabel(' vx et vy ')
plt.title( 'vx et vy en fonction de t pour t variant de t4 à t4-1')
plt.legend()
plt.show()

# %% [markdown]
# 5. Déterminer des valeurs approchées des maxima de $v_x$ et $v_y$ pour $t$ variant de $t_2-1$ à $t_2$, ainsi que les instants $t$ correspondants. Un maximum peut être en bord d'intervalle. Faire de même pour $t$ variant de $t_4-1$ à $t_4$. Commenter.

# %% [markdown]
#     Pour t variant de t2-1 à t2:
# le maxima de vx est 0.1 atteint en 2.7
# le maxima de vy est 1.7 atteint à 1.8
#
#     Pour t variant de t4-1 à t4:
# le maxima de vx est 2.2 atteint en 4
# le maxima de vy est 0 atteint 4

# %% [markdown]
# ## Partie 2

# %% [markdown]
# 6. Représenter $v_x$ et $v_y$ en fonction de $t$ pour $t$ variant de $0$ à $t_6$. On utilisera une couleur unique pour la courbe par morceaux. On remarque que $v_x$ et $v_y$ sont des fonctions continues du temps $t$. Commenter.

# %%
def time(k):
    time_= np.arange(0,k,0.01) + to*np.sqrt(np.arange(0,k,0.01))
    t=[]
    for i in time4:
        if (t[k]-1)<=i<=t[k]:
            t.append(i)
    temps=np.array(t)
    return temps

for i in range (7):
    vx= ((-1)**n)*np.sqrt(n+1)*np.sin(np.pi*(t[n]-t[i]))
    vy= ((-(-1)**n))*np.sqrt(n+1)*np.cos(np.pi*(t[n]-t[i]))

# %% [markdown]
# 7. Représenter le module de la vitesse $\sqrt{v_x^2+v_y^2}$ en fonction de $t$ pour $t$ variant de $0$ à $t_6$. On utilisera une couleur unique pour la courbe par morceaux. Commenter. A quoi sert un cyclotron ?

# %% [markdown]
# 8. Pour $n$ variant de $0$ à $50$, représenter le module de la vitesse $\sqrt{v_x(t_n)^2+v_y(t_n)^2}$ en fonction de $t_n-n$, qui est le temps total passé par le proton entre les D à l'instant $t_n$. Commenter.

# %% [markdown]
# # Compte-rendu CC Ambre LEFEVRE 21315122

# %% [markdown]
# ## Introduction
# Lors de ce CC nous allons essayer de comprendre la fonction du cyclotron, et comment modéli

# %% [markdown]
# ## Partie 1

# %% [markdown]
# - 1. Créer un tableau contenant les instants de sortie des boucles "D" :  𝑡0,  𝑡1, ... jusqu'à  𝑡50 inclus.
# On a $t_n=n+𝜏√n$.

# %%
#code pour calculer les temps 1 à 50 :
import numpy as np

n = 50
to = 0.5

# Définition de la fonction t
def t(n):
    ''' Retourne l'élément tn de la suite '''
    return n + to*np.sqrt(n)

# Liste des éléments
liste_elements = [t(k) for k in range(n)]

#appel de la fonction
t(n) 

#vérification qu'il y'a bien 50 éléments
print(len(liste_elements))

#création du tableaux des valeurs du temps avec la liste d'éléments
temps = np.array(liste_elements)

print(temps)
# Out:
# 50
# [ 0.          1.5         2.70710678  3.8660254   5.          6.11803399
#   7.22474487  8.32287566  9.41421356 10.5        11.58113883 12.6583124
#  13.73205081 14.80277564 15.87082869 16.93649167 18.         19.06155281
#  20.12132034 21.17944947 22.23606798 23.29128785 24.34520788 25.39791576
#  26.44948974 27.5        28.54950976 29.59807621 30.64575131 31.6925824
#  32.73861279 33.78388218 34.82842712 35.87228132 36.91547595 37.95803989
#  39.         40.04138127 41.082207   42.122499   43.16227766 44.20156212
#  45.24037035 46.27871926 47.31662479 48.35410197 49.39116499 50.4278273
#  51.46410162 52.5       ]

# %% [markdown]
# - 2. Vérifier que  $𝑡_1=1.5$,  $𝑡_4=5$,  $𝑡_9=10.5$,  $𝑡_16=18$, et  $𝑡_25=27.5$ avec des opérateurs booléens.

# %%
#vérification des valeurs
print(temps[1] == 1.5)
print(temps[4] == 5)
print(temps[9] == 10.5)
print(temps[16]==18)
print(temps[25] == 27.5)
# Out:
# True
# True
# True
# True
# True

# %% [markdown]
# Tout est ok.

# %% [markdown]
# - 3. Calculer les valeurs de  $𝑣_𝑥$ et  $𝑣_𝑦$ en fonction du temps pour  𝑡 variant de  $𝑡_2−1$ à  $𝑡_2$. Vous utiliserez un échantillonage suffisant pour le temps  𝑡, dans un tableau distinct de celui de la question précédente. Faire de même pour  𝑡 variant de  $𝑡_4−1$ à  $𝑡_4$.
# avec $
# v_x(t) = \epsilon_n \sqrt{n+1} \sin \left( \pi (t-t_{n+1}) \right) \qquad v_y(t) = -\epsilon_n \sqrt{n+1} \cos \left( \pi (t-t_{n+1}) \right)
# $
# avec : $
# v_x(t) = 0  \qquad  v_y(t) = \epsilon_n \left( \sqrt{n} + (t-t_n)/\tau \right)
# $

# %% [markdown]
# De $t_2-1$ à $t_2$ le proton se situe dans le D inférieur :
# ![Figure3.png](attachment:b0f50d6d-3c31-40ab-85d7-51552726d45a.png)
# on doit donc utiliser la deuxième formule des vitesses: $
# v_x(t) = \epsilon_n \sqrt{n+1} \sin \left( \pi (t-t_{n+1}) \right) \qquad v_y(t) = -\epsilon_n \sqrt{n+1} \cos \left( \pi (t-t_{n+1}) \right)
# $

# %%
#calcul des vitesses de t2-1 à t2
t = np.array(temps-1)
e = (-1)**2
pi = np.pi
n=50
# Nombre de termes
N = 10

# Définition de la fonction F
def vx(n):
    ''' Retourne la formule de la vitesse vx '''
    return e*(np.sqrt(n+1)*np.sin(pi*(n + to*np.sqrt(n)-n+1+to*np.sqrt(n+1))))

def vy(n): 
    ''' Retourne la formule de la vitesse vy '''
    return e*(np.sqrt(n+1)*np.cos(pi*(n + to*np.sqrt(n)-n+1+to*np.sqrt(n+1))))

# Liste des valeurs de vx
val_vx = [vx(k) for k in range(N)]
print("quelques valeurs de vx:",val_vx)

#liste des valeurs de vy 
val_vy = [vy(k) for k in range(N)]
print("quelques valeurs de vy:",val_vy)
# Out:
# quelques valeurs de vx: [-1.0, 0.8565889667504386, 1.686537724736652, 0.8171524660642878, -0.8102948875589686, -2.156724194895045, -2.6161986222849976, -2.079453673573953, -0.7987660261242429, 0.7973797818088324]
# quelques valeurs de vy: [-1.8369701987210297e-16, 1.1252801171448008, -0.3944496204081302, -1.825448396204355, -2.0840878568802705, -1.161266871633871, 0.3943409295952943, 1.9172564824404148, 2.891707598549633, 3.0600956657533604]

# %%
import matplotlib.pyplot as plt
plt.plot(temps[:10], val_vx)
plt.plot(temps[:10], val_vy)
plt.title("les vitesses en fonction du temps")
plt.legend(["vx", "vy"])
plt.show()

# %% [markdown]
# Maintenant concentrons-nous sur les valeurs de vitesse pour t variant de $t_2-1$ (1.70) à $t_2$ (2.70)

# %%
print(temps[2])
print(temps[2]-1)
t = np.arange(temps[2]-1, temps[2])
print(t)
plt.plot(t, val_vx[4])
plt.show()
# Out:
# 2.7071067811865475
# 1.7071067811865475
# [1.70710678]

# %% [markdown]
# ## Conclusion
# J'ai mal géré mon temps du coup je n'ai pas grand chose à conclure...

# %% [markdown]
# # CC - Physique Numérique

# %% [markdown]
# #### Mélodie ROSSI - L2 SPRINT B

# %% [markdown]
# # Particule dans un cyclotron
#
# Un cyclotron comporte trois parties, voir la figure ci-dessous. Les parties supérieure et inférieure, appelées "D" à cause de la forme de la trajectoire, sont plongées dans un champ magnétique.
#
# ![](Figure3.png)
#
# Au temps $t_0=0$ **(ici le temps est sans unité)**, un proton est injecté au niveau du D inférieur sans vitesse. Une tension alternative est appliquée entre les D. Elle crée un champ électrique dont la direction et le sens sont toujours **similaires** à ceux de la vitesse du proton lorsqu’il est entre les D. Les instants $t_n$ où le proton sort des D (soit inférieur, soit supérieur, voir la figure) sont donnés, **sans unité**, par
# $$t_n=n+\tau \sqrt{n}.$$
# On choisit $\tau=0.5$. Le temps passé par le proton dans un D (supérieur ou inférieur) est toujours de $1$.
# La trajectoire du proton est plane. On s’intéresse à sa vitesse. Ses composantes sont données, dans un repère et des unités appropriés, **en fonction de sa position dans le cyclotron:**
# 1) Pour $t$ variant de $t_n$ à $t_{n+1}-1$ c’est-à-dire quand il est entre les D :
# $$
# v_x(t) = 0  \qquad  v_y(t) = \epsilon_n \left( \sqrt{n} + (t-t_n)/\tau \right)
# $$
# 2) Pour $t$ variant de $t_{n+1}-1$ à $t_{n+1}$ c’est-à-dire quand il est dans D supérieur ou D inférieur.
# $$
# v_x(t) = \epsilon_n \sqrt{n+1} \sin \left( \pi (t-t_{n+1}) \right) \qquad v_y(t) = -\epsilon_n \sqrt{n+1} \cos \left( \pi (t-t_{n+1}) \right)
# $$
#
# Dans ces expressions, $\epsilon_n$ vaut $1$ pour $n$ pair et $-1$ pour $n$ impair. On pourra prendre $\epsilon_n = (-1)^n$.

# %% [markdown]
# ## Partie I

# %% [markdown]
# 1. Créer un tableau contenant les instants de sortie des boucles "D" : $t_0$, $t_1$, ... jusqu'à $t_{50}$ inclus.

# %%
import numpy as np
import matplotlib.pyplot as plt
import math as m

# %%
tau=0.5

# %%
t=[]
for n in range(0, 51, 1): 
    t_=n + tau*np.sqrt(n)
    t.append(t_)

# %% [markdown]
# 2. Vérifier que $t_1=1.5$, $t_4=5$, $t_9=10.5$, $t_{16}=18$, et $t_{25}=27.5$ avec des opérateurs booléens.

# %%
#On utilise l'instruction if pour exprimer une condition

if t[1]==1.5: 
    print("t_1=", t[1]) #si t[1] est égal à 1.5, alors cela renverra un message de confirmation
else :
    print("t_1 not equal to 1.5")
    
#On fait de même avec les autres valeurs
    
if t[4]==5:
    print("t_4=", t[4])
else :
    print("t_4 not equal to 5")
    
if t[9]==10.5:
    print("t_9=", t[9])
else :
    print("t_9 not equal to 10.5")
    
if t[16]==18:
    print("t_16=", t[16])
else :
    print("t_16 not equal to 18")
    
if t[25]==27.5:
    print("t_25=", t[25])
else :
    print("t_25 not equal to 27.5")
# Out:
# t_1= 1.5
# t_4= 5.0
# t_9= 10.5
# t_16= 18.0
# t_25= 27.5

# %% [markdown]
# On observe que toutes les valeurs sont vérifées.

# %% [markdown]
# 3. Calculer les valeurs de $v_x$ et $v_y$ en fonction du temps pour $t$ variant de $t_2−1$ à $t_2$. Vous utiliserez un échantillonage suffisant pour le temps $t$, dans un tableau distinct de celui de la question précédente. Faire de même pour $t$ variant de $t_4-1$ à $t_4$.

# %% [markdown]
# $t_2−1$ à $t_2$ est dans le D inférieur, on a donc :
# $$
# v_x(t) = \epsilon_n \sqrt{n+1} \sin \left( \pi (t-t_{n+1}) \right) \qquad v_y(t) = -\epsilon_n \sqrt{n+1} \cos \left( \pi (t-t_{n+1}) \right)
# $$

# %%
def epsilon_n(n):
    return (-1)**n

# %%
def vx(temps, n):
    vx_=epsilon_n(n)*np.sqrt(n+1)*np.sin(np.pi*(temps-t[n+1]))
    return vx_

# %%
def vy(temps, n):
    vy_=-epsilon_n(n)*np.sqrt(n+1)*np.cos(np.pi*(temps-t[n+1]))
    return vy_

# %% [markdown]
# Calcul des valeurs de $t_2-1$ à $t_2$

# %%
t_2=np.linspace(t[2]-1, t[2], 100) #temps variant de t[2]-1 à t[2]

# %%
vx_2=vx(t_2, 2)
vy_2=vy(t_2, 2)

# %% [markdown]
# Calcul des valeurs de $t_4-1$ à $t_4$

# %%
t_4=np.linspace(t[4]-1, t[4], 100) #temps variant de t[4]-1 à t[4]

# %%
vx_4=vx(t_4, 4)
vy_4=vy(t_4, 4)

# %% [markdown]
# 4. Représenter dans un graphique $v_x$ et $v_y$ en fonction de $t$ pour $t$ variant de $t_2-1$ a $t_2$. Faire de même pour $t$ variant de $t_4-1$ à $t_4$.

# %%
plt.plot(t_2, vx_2,  label="$v_{x_2}$")
plt.plot(t_2, vy_2, label="$v_{y_2}$")

plt.title("n=2")
plt.xlabel("$t$")
plt.ylabel("$v_x$ et $v_y$")
plt.legend()
plt.show()

# %%
plt.plot(t_4, vx_4, label="$v_{x_4}$")
plt.plot(t_4, vy_4, label="$v_{y_4}$")

plt.title("n=4")
plt.xlabel("$t$")
plt.ylabel("$v_x$ et $v_y$")
plt.legend()
plt.show()

# %% [markdown]
# 5. Déterminer des valeurs approchées des maxima de $v_x$ et $v_y$ pour $t$ variant de $t_2-1$ à $t_2$, ainsi que les instants $t$ correspondants. Un maximum peut être en bord d'intervalle. Faire de même pour $t$ variant de $t_4-1$ à $t_4$. Commenter.

# %%
max_vx2=max(vx_2) #renvoie le maximum de la liste
print(max_vx2)
# Out:
# 1.732003485936772

# %%
max_vy2=max(vy_2) #renvoie le maximum de la liste
print(max_vy2)
# Out:
# 1.5206336660206556

# %%
max_vx4=max(vx_4) #renvoie le maximum de la liste
print(max_vx4)
# Out:
# 2.236029292905328

# %%
max_vy4=max(vy_4) #renvoie le maximum de la liste
print(max_vy4)
# Out:
# 2.0840878568802705

# %% [markdown]
# On observe que max_vx2 < max_vx4 et max_vy2 < max_vy4. Ainsi, nous pouvons en déduire que la vitesse augmente au cours du temps.

# %% [markdown]
# ## Partie II

# %% [markdown]
# 6. Représenter $v_x$ et $v_y$ en fonction de $t$ pour $t$ variant de $0$ à $t_6$. On utilisera une couleur unique pour la courbe par morceaux. On remarque que $v_x$ et $v_y$ sont des fonctions continues du temps $t$. Commenter.

# %%
t_6=np.linspace(0, t[6], 100)

# %%
plt.plot(t_6, vx(t_6, 6), label="$v_x$", color='red')
plt.plot(t_6, vy(t_6, 6), label="$v_y$", color='pink')

plt.title("n=6")
plt.xlabel("$t$")
plt.ylabel("$v_x$ et $v_y$")
plt.legend()
plt.show()

# %% [markdown]
# Je ne vois pas de courbe par morceaux. Ceci dit, $v_x$ et $v_y$ semble les mêmes mais décalées. Cela suggère une vitesse totale qui varie beaucoup. Mais $v_x$ et $v_y$ ont une amplitude d'environ 2 (en regardant la valeur absolue)

# %% [markdown]
# 7. Représenter le module de la vitesse $\sqrt{v_x^2+v_y^2}$ en fonction de $t$ pour $t$ variant de $0$ à $t_6$. On utilisera une couleur unique pour la courbe par morceaux. Commenter. A quoi sert un cyclotron ?

# %%
def module_v(temps):
    v=np.sqrt(vx(temps, 6)**2+vy(temps, 6)**2)
    return v

# %%
module_v=np.sqrt(vx(t_6, 6)**2+vy(t_6, 6)**2)
print(type(module_v))
# Out:
# <class 'numpy.ndarray'>

# %%
t_n=[]
module_v_n=[]
for n in range(0, 50, 1):   
    module_v_=np.sqrt(vx(t_6, n)**2+vy(t_6, n)**2)
    module_v_n.append(module_v_)

# %%
plt.plot(t_6, module_v, label="$||v||$")

plt.title("n=6")
plt.xlabel("$t$")
plt.ylabel("$v$")
plt.legend()
plt.show()

# %% [markdown]
# Le module de la vitesse semble rester constante.
# Un cyclotron semble servir à garder l'électron à une vitesse constante (d'après les résultats obtenus).
# C'est un intervalle de temps assez petit pour ne pas voir de fluctuations dans le module de la vitesse.

# %% [markdown]
# 8. Pour $n$ variant de $0$ à $50$, représenter le module de la vitesse $\sqrt{v_x(t_n)^2+v_y(t_n)^2}$ en fonction de $t_n-n$, qui est le temps total passé par le proton entre les D à l'instant $t_n$. Commenter.

# %%
t_n=[]
t_n_n=[]
module_v_n=[]
for n in range(0, 50, 1): #50 pour ne pas avoir de problèmes d'index out of range, lors du calcul t[n+1] 
    t_n_=n+tau*np.sqrt(n)
    t_n.append(t_)   
    t_n_n_=t_n[n]-n
    t_n_n.append(t_n_n_)
    module_v_=np.sqrt(vx(t_n_, n)**2+vy(t_n_, n)**2)
    module_v_n.append(module_v_)
    
print(t_n_n, t_n)
print(module_v_n)
# Out:
# [53.53553390593274, 52.53553390593274, 51.53553390593274, 50.53553390593274, 49.53553390593274, 48.53553390593274, 47.53553390593274, 46.53553390593274, 45.53553390593274, 44.53553390593274, 43.53553390593274, 42.53553390593274, 41.53553390593274, 40.53553390593274, 39.53553390593274, 38.53553390593274, 37.53553390593274, 36.53553390593274, 35.53553390593274, 34.53553390593274, 33.53553390593274, 32.53553390593274, 31.535533905932738, 30.535533905932738, 29.535533905932738, 28.535533905932738, 27.535533905932738, 26.535533905932738, 25.535533905932738, 24.535533905932738, 23.535533905932738, 22.535533905932738, 21.535533905932738, 20.535533905932738, 19.535533905932738, 18.535533905932738, 17.535533905932738, 16.535533905932738, 15.535533905932738, 14.535533905932738, 13.535533905932738, 12.535533905932738, 11.535533905932738, 10.535533905932738, 9.535533905932738, 8.535533905932738, 7.535533905932738, 6.535533905932738, 5.535533905932738, 4.535533905932738] [53.53553390593274, 53.53553390593274, 53.53553390593274, 53.53553390593274, 53.53553390593274, 53.53553390593274, 53.53553390593274, 53.53553390593274, 53.53553390593274, 53.53553390593274, 53.53553390593274, 53.53553390593274, 53.53553390593274, 53.53553390593274, 53.53553390593274, 53.53553390593274, 53.53553390593274, 53.53553390593274, 53.53553390593274, 53.53553390593274, 53.53553390593274, 53.53553390593274, 53.53553390593274, 53.53553390593274, 53.53553390593274, 53.53553390593274, 53.53553390593274, 53.53553390593274, 53.53553390593274, 53.53553390593274, 53.53553390593274, 53.53553390593274, 53.53553390593274, 53.53553390593274, 53.53553390593274, 53.53553390593274, 53.53553390593274, 53.53553390593274, 53.53553390593274, 53.53553390593274, 53.53553390593274, 53.53553390593274, 53.53553390593274, 53.53553390593274, 53.53553390593274, 53.53553390593274, 53.53553390593274, 53.53553390593274, 53.53553390593274, 53.53553390593274]
# [1.0, 1.4142135623730954, 1.732050807568877, 1.9999999999999998, 2.23606797749979, 2.449489742783178, 2.645751311064591, 2.828427124746191, 3.000000000000001, 3.16227766016838, 3.3166247903554003, 3.464101615137755, 3.60555127546399, 3.7416573867739413, 3.8729833462074175, 4.0, 4.1231056256176615, 4.242640687119285, 4.358898943540674, 4.47213595499958, 4.58257569495584, 4.69041575982343, 4.795831523312719, 4.898979485566356, 4.999999999999999, 5.0990195135927845, 5.196152422706631, 5.2915026221291805, 5.385164807134503, 5.477225575051661, 5.5677643628300215, 5.656854249492381, 5.744562646538028, 5.8309518948453, 5.916079783099616, 5.999999999999999, 6.0827625302982185, 6.164414002968975, 6.244997998398397, 6.324555320336757, 6.403124237432848, 6.4807406984078595, 6.5574385243019995, 6.633249580710798, 6.708203932499369, 6.782329983125268, 6.855654600401044, 6.928203230275508, 6.999999999999999, 7.0710678118654755]

# %%
plt.plot(t_n_n, module_v_n, color='blue')

plt.title("module de v")
plt.xlabel("$t_n-n$")
plt.ylabel("$||v||$")
plt.show()

# %% [markdown]
# On observe que plus le temps passé entre les D ($t_n-n$) augmente, plus le module de la vitesse diminue.

# %% [markdown]
# # CC 1
#
# ## Partie 1

# %%
# importation des modules 
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# 1)


#A = np.ones(50)  # creation d'un tableau 
#print(A)


# on fait le tableau pour les temps 
for i in range(0, 51):
   t[i] = i + T * np.sqrt(i)

print(t)
# Out:
# [  0.           1.5          2.70710678   3.8660254    5.
#    6.11803399   7.22474487   8.32287566   9.41421356  10.5
#   11.58113883  12.6583124   13.73205081  14.80277564  15.87082869
#   16.93649167  18.          19.06155281  20.12132034  21.17944947
#   22.23606798  23.29128785  24.34520788  25.39791576  26.44948974
#   27.5         28.54950976  29.59807621  30.64575131  31.6925824
#   32.73861279  33.78388218  34.82842712  35.87228132  36.91547595
#   37.95803989  39.          40.04138127  41.082207    42.122499
#   43.16227766  44.20156212  45.24037035  46.27871926  47.31662479
#   48.35410197  49.39116499  50.4278273   51.46410162  52.5
#   53.53553391   5.10510511   5.20520521   5.30530531   5.40540541
#    5.50550551   5.60560561   5.70570571   5.80580581   5.90590591
#    6.00600601   6.10610611   6.20620621   6.30630631   6.40640641
#    6.50650651   6.60660661   6.70670671   6.80680681   6.90690691
#    7.00700701   7.10710711   7.20720721   7.30730731   7.40740741
# ...

# %%
#on verifie à l'aide d'opérateur boléens 

print(t_1 ==  1.5)
print(t_4 ==  5)
print(t_9 == 10.5)
print(t_16 == 18) 
print(t_25 == 17.5)

# en lisant sur le tableau precedent, on voit que ces valeurs correspondent bien, le script devrait nous renvoyer 'TRUE'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[60], line 3
#       1 #on verifie à l'aide d'opérateur boléens
# ----> 3 print(t_1 ==  1.5)
#       4 print(t_4 ==  5)
#       5 print(t_9 == 10.5)
#
# NameError: name 't_1' is not defined

# %%
#3 
t_2 = 2.70710678 # d'apres le tableau de la question 1 
t_4 = 5  # d'apres le tableau de la question 1

#on définit une fonction car la vitesse depend de t
n=1
E_n = -1 # n est impair donc E=-1

# pour le premier intervalle de temps de t_2-1 à t_2,
t = np.linspace(0, 100, 1000) 

# pour v_x
def v_x1(t): 
    return E_n * np.sqrt(n-1) * np.sin(np.pi*(t - t_2))
print(v_x1)

    
# pour v_y
def v_y1(t): 
    return -E_n * np.sqrt(n-1) * np.cos(np.pi*(t - t_2))
print(v_y1)
  


# on fait la meme chose pour le deuxieme intervalle 

n_2 = 3
E_n = -1 # n est impair donc E=-1


# pour v_x
def v_x2(t): 
    return E_n * np.sqrt(n_2-1) * np.sin(np.pi*(t - t_2))
print(v_x2)

    
# pour v_y
def v_y2(t): 
    return -E_n * np.sqrt(n_2-1) * np.cos(np.pi*(t - t_2))
print(v_y2)
# Out:
# <function v_x1 at 0x7f0c217e4310>
# <function v_y1 at 0x7f0c217e4c10>
# <function v_x2 at 0x7f0c259adf70>
# <function v_y2 at 0x7f0c257ebf70>

# %%
# 4) Representation graphique

# pour  t_2-1 à t_2

#plot de v_x1

t = np.linspace(0, 100, 1000)
plt.plot(t, v_x1(t))
plt.xlabel("temps")
plt.ylabel("v_x1")
plt.title("vitesse selon x en fonction du temps")
# Out:
# Text(0.5, 1.0, 'vitesse selon x en fonction du temps')

# %%
#plot de v_y1

t = np.linspace(0, 100, 1000)
plt.plot(t, v_y1(t))
plt.xlabel("temps")
plt.ylabel("v_y1")
plt.title("vitesse selon y en fonction du temps")
# Out:
# Text(0.5, 1.0, 'vitesse selon y en fonction du temps')

# %%
# pour  t_4-1 à t_4

#plot de v_x2

t = np.linspace(0, 100, 1000)
plt.plot(t, v_x2(t))
plt.xlabel("temps")
plt.ylabel("v_x2")
plt.title("vitesse selon x en fonction du temps")
# Out:
# Text(0.5, 1.0, 'vitesse selon x en fonction du temps')

# %%
#plot de v_y2

t = np.linspace(0, 100, 1000)
plt.plot(t, v_y2(t))
plt.xlabel("temps")
plt.ylabel("v_y2")
plt.title("vitesse selon y en fonction du temps")
# Out:
# Text(0.5, 1.0, 'vitesse selon y en fonction du temps')

# %%
# 5) Maxima de v_x et v_y 

# pour  t_2-1 à t_2

#pour v_x1
def max(t):
    M = max(v_x1)
    return M

print(M)

#pour v_y1
def max(t):
    N = max(v_y1)
    return N

print(N)

# pour  t_4-1 à t_4
#pour v_x2
def max(t):
    J = max(v_x2)
    return J

print(J)

#pour v_y2
def max(t):
    K = max(v_y2)
    return K
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[67], line 10
#       7     M = max(v_x1)
#       8     return M
# ---> 10 print(M)
#      12 #pour v_y1
#      13 def max(t):
#
# NameError: name 'M' is not defined

# %% [markdown]
# ## partie 2

# %%
#pout t varient de 0 à t_6 

t_6 = 7.22474487

# pour le premier intervalle de temps ,
t = np.linspace(0, 100, 1000) 

# pour v_x
def v_x3(t): 
    return E_n * np.sqrt(n-1) * np.sin(np.pi*(t - t_6))
print(v_x1)

    
# pour v_y
def v_y3(t): 
    return -E_n * np.sqrt(n-1) * np.cos(np.pi*(t - t_6))
print(v_y1)
# Out:
# <function v_x1 at 0x7f0c217e4310>
# <function v_y1 at 0x7f0c217e4c10>

# %% [markdown]
# # Contrôle Continu - LU2PY222
#
# ## Partie 1

# %%
# Importation des modules
import numpy as np
import matplotlib.pyplot as plt

# Définition des variables
tau = 0.5
n = np.arange(0,51,1)
t = np.linspace(0,50,1000)

# Création de la boucle permettant de calculer les instants tn
for i in range (0,51,1):
    t[i] = i + tau*np.sqrt(i)         # Tableau des instants tn

# Vérifiacation de quelques valeurs connues
print(t[1] == 1.5)
print(t[4] == 5)
print(t[9] == 10.5)
print(t[16] == 18)
print(t[25] == 27.5)
# Out:
# True
# True
# True
# True
# True

# %%
print(t[2])
print(t[2]-1)
# Out:
# 2.7071067811865475
# 1.7071067811865475

# %%
epsilon2 = -1
temps = np.linspace(1.71,2.71,1000)
Vx2 = np.ones(1000)
Vy2 = np.ones(1000)
Vx4 = np.ones(1000)
Vy4 = np.ones(1000)

for i in range (len(temps)):
    Vx2[i] = epsilon2*np.sqrt(2)*np.sin(np.pi*temps[i]-t[2])
    Vy2[i] = -epsilon2*np.sqrt(2)*np.cos(np.pi*temps[i]-t[2])
    
for i in range (len(temps)):
    Vx4[i] = epsilon2*np.sqrt(4)*np.sin(np.pi*temps[i]-t[4])
    Vy4[i] = -epsilon2*np.sqrt(4)*np.cos(np.pi*temps[i]-t[4])

print(Vx3)
print(Vy3)
# Out:
# [-0.64875548 -0.64480051 -0.64083917 ...  0.65270404  0.64875548
#   1.        ]
# [-1.25662895 -1.2586629  -1.2606844  ...  1.25458258  1.25662895
#   1.        ]

# %%
# Tracé du graphe
plt.plot(t,Vx2, label = "Vitesse horzontale")
plt.plot(t,Vy2, label = "Vitesse verticale")
plt.title("Vitesses verticales et horizontales en fonction du temps entre t2 et t2-1")
plt.xlabel("Temps (en s)")
plt.ylabel("Vitesses (en m/s)")
plt.legend()
plt.grid()
plt.show()

# %%
# Tracé du graphe
plt.plot(t,Vx4, label = "Vitesse horzontale")
plt.plot(t,Vy4, label = "Vitesse verticale")
plt.title("Vitesses verticales et horizontales en fonction du temps entre t4 et t4-1")
plt.xlabel("Temps (en s)")
plt.ylabel("Vitesses (en m/s)")
plt.legend()
plt.grid()
plt.show()

# %%
derivee = np.zeros(len(temps) - 1)

for i in range(len(t) - 1): 
    derivee[i] = (Vy2[i + 1] - Vy2[i]) / (t[i + 1] - t[i])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[70], line 6
#       3 for i in range(len(t) - 1):
#       4     derivee[i] = (Vy2[i + 1] - Vy2[i]) / (t[i + 1] - t[i])
# ----> 6 plt.plot(len(t)-1,derivee)
#
# File /opt/tljh/user/lib/python3.9/site-packages/matplotlib/pyplot.py:2812, in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# File /opt/tljh/user/lib/python3.9/site-packages/matplotlib/axes/_axes.py:1688, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1445 """
#    1446 Plot y versus x as lines and/or markers.
#    1447
#    (...)
# ...

# %% [markdown]
# ## Partie 2
